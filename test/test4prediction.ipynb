# %%
import tensorflow as tf

# %%
print(f"TensorFlow has access to the following devices:\n{tf.config.list_physical_devices()}")
# Out:
# TensorFlow has access to the following devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import ORIENT as ot
# Out:
# /Users/donglaima/tensorflow-test/env/lib/python3.8/site-packages/pytplot_mpl_temp-2.0.5-py3.8.egg/pytplot/timestamp.py:28: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if val is 'on':

# %%
import ORIENT as ot


from datetime import datetime

start_time = datetime(2013,3,15)
end_time = datetime(2013,3,20)
input_time =  datetime(2013,3,19,3)

eflux_1 =  ot.eflux.model.ElectronFlux(start_time, end_time,instrument = 'mageis',channel = 11)
final_frame, X_input_total = eflux_1.get_flux(dst_source='omni',
                 al_source='omni',
                 sw_source='omni',use_omni = True,use_traj = False,get_input_time = input_time,get_MLT_flux=True,
                                             selected_MLT_datetime = input_time)
# Out:
# 18-May-22 15:27:03: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/omni/omni_cdaweb/hro2_5min/2013/
# version DM
# startmin -14400
# endmin 0
# lagstep 60
# input ['al', 'dst', 'pressure', 'flow_speed']
# ORIENT-M initialized, Getting eflux from: mageis channel: 11
# Start loading the data... np_update is: False
# Get MLT flux mode is on
# 18-May-22 15:27:03: File is current: omni_data/hro2_5min/2013/omni_hro2_5min_20130301_v01.cdf
# 18-May-22 15:27:03: /Users/donglaima/Research/Code/ORIENT-main/ORIENT/eflux/model.py:332: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame_return[name_t] = item_i
# filling gap of ['AE_INDEX', 'AL_INDEX', 'SYM_H', 'flow_speed', 'Pressure', 'BZ_GSM']
# ...

# %%
eflux_1.make_plot(normmax = 10**4.7)

# %%
eflux_2 =  ot.eflux.model.ElectronFlux(start_time, end_time,instrument = 'mageis',channel = 16)
final_frame, X_input_total = eflux_2.get_flux(dst_source='omni',
                 al_source='omni',
                 sw_source='omni',use_omni = True,use_traj = False,get_input_time = input_time,get_MLT_flux=True,
                                             selected_MLT_datetime = input_time)
# Out:
# 18-May-22 15:27:13: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/omni/omni_cdaweb/hro2_5min/2013/
# version DM
# startmin -25920
# endmin 0
# lagstep 120
# input ['al', 'dst', 'pressure', 'flow_speed']
# ORIENT-M initialized, Getting eflux from: mageis channel: 16
# Start loading the data... np_update is: False
# Get MLT flux mode is on
# 18-May-22 15:27:14: File is current: omni_data/hro2_5min/2013/omni_hro2_5min_20130201_v01.cdf
# 18-May-22 15:27:14: File is current: omni_data/hro2_5min/2013/omni_hro2_5min_20130301_v01.cdf
# 18-May-22 15:27:14: /Users/donglaima/Research/Code/ORIENT-main/ORIENT/eflux/model.py:332: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame_return[name_t] = item_i
#
# ...

# %%
eflux_2.make_plot(normmax = 10**3.8)

# %%
eflux_3 =  ot.eflux.model.ElectronFlux(start_time, end_time,instrument = 'mageis',channel = 14)
final_frame, X_input_total = eflux_3.get_flux(dst_source='omni',
                 al_source='omni',
                 sw_source='omni',use_omni = True,use_traj = False,get_input_time = input_time,get_MLT_flux=True,
                                             selected_MLT_datetime = input_time)
# Out:
# 18-May-22 15:27:23: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/omni/omni_cdaweb/hro2_5min/2013/
# version DM
# startmin -20160
# endmin 0
# lagstep 90
# input ['al', 'dst', 'pressure', 'flow_speed']
# ORIENT-M initialized, Getting eflux from: mageis channel: 14
# Start loading the data... np_update is: False
# Get MLT flux mode is on
# 18-May-22 15:27:24: File is current: omni_data/hro2_5min/2013/omni_hro2_5min_20130201_v01.cdf
# 18-May-22 15:27:24: File is current: omni_data/hro2_5min/2013/omni_hro2_5min_20130301_v01.cdf
# 18-May-22 15:27:24: /Users/donglaima/Research/Code/ORIENT-main/ORIENT/eflux/model.py:332: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   frame_return[name_t] = item_i
#
# ...

# %%
# test make real flux plot
eflux_3.make_plot(normmax = 10**4.1)

# %%
import ORIENT as ot
ot.eflux.data_assemble(selfmade_dir ='/Users/donglaima/Research/data/selfmade/' ,
                       omni_dir = '/Users/donglaima/Research/data/omni/',
                       channel=16,instrument_name='mageis',startmin=-72*18*20,lagstep=120,sincos = True,
                                         varname=['AL_INDEX','SYM_H','Pressure','flow_speed'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 import ORIENT as ot
# ----> 2 ot.eflux.data_assemble(selfmade_dir ='/Users/donglaima/Research/data/selfmade/' ,
#       3                        omni_dir = '/Users/donglaima/Research/data/omni/',
#       4                        channel=16,instrument_name='mageis',startmin=-72*18*20,lagstep=120,sincos = True,
#       5                                          varname=['AL_INDEX','SYM_H','Pressure','flow_speed'])
#
# File ~/Research/Code/ORIENT-main/ORIENT/eflux/data_assemble.py:37, in data_assemble(selfmade_dir, omni_dir, startmin, endmin, lagstep, res, avgflag, instrument_name, probe, varname, position_name, channel, sincos, fl32)
#      35 lag_name = []
#      36 for i,name in zip(range(len(varname)),varname):
# ...
